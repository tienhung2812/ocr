# %%
import os
from langdetect import detect
import pandas as pd
import json

MIN_ACCEP_CATE_CONF = 0.52

media_path = '../../main/media'

total_transaction = len(os.listdir(path=media_path))

print("Total transaction: ",total_transaction)

df_col = ["sentence","brand_name","info","index","content","total","thank_you"]
# Out:
# Total transaction:  38

# %%
# Find data file
train_df = pd.DataFrame(columns=df_col)

i = 0
for transaction in os.listdir(path=media_path):
    data_json_path = media_path+"/"+transaction+'/text_detection/data.json'
    if os.path.exists(data_json_path):
            with open(data_json_path) as f:
                current_data = json.load(f)
                for index, row in enumerate(current_data):
                    usable_data = current_data[row]
# Out:
# {'sentence': 'FC GOOD COFEE', 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': 'ĐC: 126 Lai Hùng Cường, Vĩnh Lọc B,', 'cate': 'info', 'cate_conf': '0.99430096'}
# {'sentence': 'Bình Chánh, TpHCM', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'ĐT: 0934145879', 'cate': 'info', 'cate_conf': '0.7213746'}
# {'sentence': 'HOA DON BAN HANG', 'cate': 'info', 'cate_conf': '0.9996594'}
# {'sentence': 'A09', 'cate': 'total', 'cate_conf': 0}
# {'sentence': 'Ngày: 25/03/2019 Số: 031900002', 'cate': 'info', 'cate_conf': '0.9999248'}
# {'sentence': 'Thu ngan: Administrator In lúc: 15:38', 'cate': 'info', 'cate_conf': '0.9992699'}
# {'sentence': 'Giờ vao: 15:36', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Gio ra: 15:36', 'cate': 'info', 'cate_conf': 1}
# {'sentence': '[rẻ sảng [st [pvt [Gia [Tr tien', 'cate': 'total', 'cate_conf': 0}
# {'sentence': '|haiđâu) | +[ chal} 33,000... 33ogol', 'cate': 'total', 'cate_conf': 0}
# {'sentence': '| Heiniken lon', 'cate': 'total', 'cate_conf': 0}
# {'sentence': '+} lôn| 35,000] 3s,00gị', 'cate': 'thank_you', 'cate_conf': 0}
# {'sentence': 'Tổng:', 'cate': 'total', 'cate_conf': 1}
# {'sentence': '68,000', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'Cảm ơn Quý khách. Hẹn gặp lại!', 'cate': 'thank_you', 'cate_conf': 1}
# {'sentence': 'PASARAYA BORONG PINTAR', 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': 'SDN BHD', 'cate': 'brand_name', 'cate_conf': '0.5292906'}
# {'sentence': 'BR No.: (124525-H).', 'cate': 'brand_name', 'cate_conf': '0.4963469'}
# {'sentence': 'NO 19-G&19-1&19-2 JALAN TASIK UTAMA 4,', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'MEDAN NIAGA TASIK DAMAI', 'cate': 'info', 'cate_conf': 1}
# {'sentence': '016-5498845,', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'GST No. :', 'cate': 'info', 'cate_conf': 1}
# {'sentence': '14/03/2018 4:06:34PM', 'cate': 'info', 'cate_conf': '0.9996855'}
# {'sentence': 'TAX INVOICE', 'cate': 'info', 'cate_conf': '0.99993026'}
# {'sentence': 'TRRN: CRO00895B', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'COUNTER 3 CASHIER: 1', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'QTY UOM UNITAmt Exc. Amt Inc. GST', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Price Tax Tax Code', 'cate': 'index', 'cate_conf': 1}
# {'sentence': 'GB CR-CORN', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'WALK 0.90 0.90 0.90 ZRL', 'cate': 'content', 'cate_conf': '0.9829486'}
# {'sentence': '*Total Qty: 1.00 0.90', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'Total Includes GST 0% 0.90', 'cate': 'total', 'cate_conf': 1}
# {'sentence': "Customer's Payment", 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': 'Cash 5.00', 'cate': 'total', 'cate_conf': '0.81326944'}
# {'sentence': 'Change 4.10', 'cate': 'total', 'cate_conf': '0.9475196'}
# {'sentence': 'GST Summary Amount (RM) Tax (RM)', 'cate': 'index', 'cate_conf': 1}
# {'sentence': 'ZRL=0% 0.90 0.00', 'cate': 'content', 'cate_conf': '0.5133899'}
# {'sentence': '“Goods sold are not returnable', 'cate': 'thank_you', 'cate_conf': '0.9152272'}
# {'sentence': 'Thank you for shopping at PASARAYA', 'cate': 'thank_you', 'cate_conf': '0.82910097'}
# {'sentence': 'BORONG PINTAR SDN BHD', 'cate': 'brand_name', 'cate_conf': '0.5292906'}
# {'sentence': '184.0', 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': 'Gerbang Alaf Restaurants Sdn Bhd', 'cate': 'brand_name', 'cate_conf': '0.5292906'}
# {'sentence': '(B5351-M)', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'Licensee of McBenald’s', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Level G, Bangunan TH, Demensara Uotound', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'No.3, Jalan $$21/39,47400 Petaling Jaya', 'cate': 'info', 'cate_conf': '0.9983677'}
# {'sentence': 'Selangor', 'cate': 'info', 'cate_conf': '0.8878318'}
# {'sentence': '(GST ID Ne: 0900504664064)', 'cate': 'info', 'cate_conf': 1}
# {'sentence': "| McDonald's Shell Mahkota Cheras DT (436", 'cate': 'info', 'cate_conf': '0.8881962'}
# {'sentence': 'Tal No. 03-8010-9849', 'cate': 'info', 'cate_conf': '0.8769545'}
# {'sentence': 'TAX INVOICE', 'cate': 'info', 'cate_conf': '0.99993026'}
# {'sentence': 'RFY Side 1', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'TNV# 00262 1900844541)', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'ORD #64 -REG #19- 30/05/2018 16:07:06', 'cate': 'info', 'cate_conf': '0.9999707'}
# {'sentence': 'QTY ITEM TOTAL', 'cate': 'index', 'cate_conf': 1}
# {'sentence': '2 H McPhickEn 1.00', 'cate': 'content', 'cate_conf': '0.9543954'}
# {'sentence': '74 ke', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '2 M Fries', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'TakeQut Total (inci GST) 198.00', 'cate': 'total', 'cate_conf': '0.86870193'}
# {'sentence': 'Total Rounded 19.00', 'cate': 'total', 'cate_conf': '0.95571893'}
# {'sentence': '| Pash Terdered 50,00', 'cate': 'total', 'cate_conf': '0.6982207'}
# {'sentence': '- /Ê]hahge 31,00', 'cate': 'total', 'cate_conf': '0.95580506'}
# {'sentence': '| TOTAL INCLUDES 6% GST 1.08', 'cate': 'total', 'cate_conf': '0.977258'}
# {'sentence': 'Thank You and Please Come Again.', 'cate': 'thank_you', 'cate_conf': '0.9580079'}
# {'sentence': 'Guest Relations Canter : 1300-13-i3800', 'cate': 'total', 'cate_conf': '0.7990772'}
# {'sentence': '2180303.0', 'cate': 'info', 'cate_conf': '0.30173048'}
# {'sentence': 'UAN HING STATIONERY SDN BHD', 'cate': 'brand_name', 'cate_conf': '0.5292906'}
# {'sentence': '(162761-M)', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'NO.92 & 33, JALAN SR 1.9. SEKSYEN 9.', 'cate': 'total', 'cate_conf': '0.9737051'}
# {'sentence': 'TAMAN SERDANG RAYA,', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': '43300 SERI KEMBAN/(SAH. SELANGOR', 'cate': 'info', 'cate_conf': '0.9989122'}
# {'sentence': 'BARUL EHSAN', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': 'GST ID : 002139201536', 'cate': 'total', 'cate_conf': '0.5571397'}
# {'sentence': 'Tax Invoice', 'cate': 'info', 'cate_conf': '0.99993026'}
# {'sentence': '22042018 — _—__ No.:CS-20242', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Qty Tax RM', 'cate': 'info', 'cate_conf': '0.9408327'}
# {'sentence': 'Dursfile H399 (110 x 95mm) 100 SR 58.30', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Name Badge {Hj @ 0.5500', 'cate': 'info', 'cate_conf': '0.30173048'}
# {'sentence': '809 Metal Neme Badge Clip 1 SR 2120', 'cate': 'content', 'cate_conf': 1}
# {'sentence': "~- 100's @ 20 0000", 'cate': 'total', 'cate_conf': '0.830748'}
# {'sentence': 'Total Amt Incl. GST @ 6% : 7950 ⁄', 'cate': 'total', 'cate_conf': '0.92680156'}
# {'sentence': 'Rounding Adjusunent', 'cate': 'info', 'cate_conf': '0.42538878'}
# {'sentence': '', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Paid Amount 100.00', 'cate': 'total', 'cate_conf': '0.9552349'}
# {'sentence': 'Change : 20.50', 'cate': 'total', 'cate_conf': '0.81295234'}
# {'sentence': 'Tota Qry Tender : 101', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': '!GST Summary  AmeunL Tax :', 'cate': 'info', 'cate_conf': '0.9953687'}
# {'sentence': '(RM) (RM) :', 'cate': 'brand_name', 'cate_conf': '0.50509363'}
# {'sentence': '‘SR@A 00 450:', 'cate': 'total', 'cate_conf': '0.5530033'}
# {'sentence': '¡ Total 75.00 4.50 :', 'cate': 'total', 'cate_conf': 1}
# {'sentence': '“THANK YOU', 'cate': 'thank_you', 'cate_conf': '0.6936264'}
# {'sentence': 'Far anv enauiry oleaase cantact in', 'cate': 'thank_you', 'cate_conf': 1}
# {'sentence': 'RESTORAN WAN SHENG |', 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': '002043319-W', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'No.2, Jalan Temenggung 19/9,', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Seksyen 9, Bandar Mahkota Cheras,', 'cate': 'info', 'cate_conf': 1}
# {'sentence': '43200 Cheras, Selangor', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'GST REG NO: 001335787520', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Tax Invoice', 'cate': 'info', 'cate_conf': '0.99993026'}
# {'sentence': 'INY No.: 1075214 Cashier: Thandar', 'cate': 'info', 'cate_conf': '0.8916585'}
# {'sentence': 'Pate _ : 02042018 19:30:28', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Description Qty U.price Total TAX', 'cate': 'index', 'cate_conf': 1}
# {'sentence': 'MiIo (B)', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '2 2.80 5.60 SR', 'cate': 'content', 'cate_conf': '0.99892825'}
# {'sentence': 'Take Away', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '2x 0.20 0.40 SR', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Total OTY: 4', 'cate': 'total', 'cate_conf': '0.96895164'}
# {'sentence': '101a1 (Excluding GST) : 6A', 'cate': 'total', 'cate_conf': '0.89053726'}
# {'sentence': 'AST payable (6%): UL 34', 'cate': 'content', 'cate_conf': '0.55889326'}
# {'sentence': 'total (tínclusive of 6SI): _ 6.00', 'cate': 'total', 'cate_conf': '0.9779886'}
# {'sentence': 'TOFAI.: / 6.00', 'cate': 'total', 'cate_conf': '0.8880731'}
# {'sentence': 'CASH: 6.00', 'cate': 'total', 'cate_conf': '0.9480787'}
# {'sentence': 'GST Summary Anount (RM) — Tax(RM)', 'cate': 'index', 'cate_conf': 1}
# {'sentence': 'SR (@ 6%) 5.66 0.34', 'cate': 'total', 'cate_conf': '0.8833316'}
# {'sentence': 'Bsc', 'cate': 'total', 'cate_conf': 0}
# {'sentence': 'tinh LẦU re as) A', 'cate': 'content', 'cate_conf': 0}
# {'sentence': 'CUA HANG ĐẠI VIỆT', 'cate': 'info', 'cate_conf': '0.98172116'}
# {'sentence': 'Ðe: Nguyễn Văn Nguy - Nga hanh Sơn -', 'cate': 'info', 'cate_conf': '0.9091903'}
# {'sentence': 'EN', 'cate': 'total', 'cate_conf': 0}
# {'sentence': 'Hotline : 091554 05 06', 'cate': 'info', 'cate_conf': '0.998976'}
# {'sentence': 'HÓA ĐƠN THANH TOÁN', 'cate': 'info', 'cate_conf': '0.9996686'}
# {'sentence': 'HB: 0002', 'cate': 'info', 'cate_conf': '0.9977216'}
# {'sentence': 'Ngày 23/04/2018 Giờ 00:39:24.', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Khách hàng:', 'cate': 'info', 'cate_conf': '0.50603986'}
# {'sentence': 'TÊN HÀNG ˆ', 'cate': 'content', 'cate_conf': '0.7501377'}
# {'sentence': 'SL  ĐGIÁ TTIÊN', 'cate': 'index', 'cate_conf': 1}
# {'sentence': 'Sting Vang', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': '0 ae ee', 'cate': 'info', 'cate_conf': 0}
# {'sentence': '90,000 50,000', 'cate': 'content', 'cate_conf': '0.9934691'}
# {'sentence': 'ca phê sữa:', 'cate': 'content', 'cate_conf': '0.99916625'}
# {'sentence': '30,000 30,000', 'cate': 'content', 'cate_conf': '0.99998844'}
# {'sentence': 'ca phê đen', 'cate': 'content', 'cate_conf': '0.99645656'}
# {'sentence': '_ 20,000 20/000', 'cate': 'content', 'cate_conf': '0.94475454'}
# {'sentence': 'T.CÔNG:', 'cate': 'total', 'cate_conf': '0.9339436'}
# {'sentence': 'Tiền mặt 112.000', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'TƯỜNG 112,000', 'cate': 'total', 'cate_conf': 0}
# {'sentence': 'TỶ giá 35', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'Một trăm mười hai ngàn đồng', 'cate': 'total', 'cate_conf': 1}
# {'sentence': '3,200', 'cate': 'total', 'cate_conf': 0}
# {'sentence': 'CẢM ƠN, XIN GẶP LẠI !', 'cate': 'thank_you', 'cate_conf': 1}
# {'sentence': 'PHTÊU TTNH TIŒN:', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': 'Tiên :¡ 1 20/10/2026 1:03109A', 'cate': 'content', 'cate_conf': '0.9913119'}
# {'sentence': 'SOH.DON;, 00001-20102014601', 'cate': 'info', 'cate_conf': '0.7339509'}
# {'sentence': 'RAN,', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': 'NHAN VION:', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': 'Phục vụ:', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': 'GloeVaox 20/10/20141:00118A', 'cate': 'total', 'cate_conf': '0.9263315'}
# {'sentence': 'gio Ra : 20/10/2014 4103106 A', 'cate': 'info', 'cate_conf': '0.9959781'}
# {'sentence': 'TOUISL GT', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': '4 x 90,000,000 360,000,000', 'cate': 'content', 'cate_conf': '0.9999863'}
# {'sentence': 'SHISHA', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': '2.x 1,000,000 2,000,000', 'cate': 'content', 'cate_conf': '0.9999938'}
# {'sentence': 'VOT VOT CANADA', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': '3 x 10,000,000 30,000,000', 'cate': 'content', 'cate_conf': '0.99999857'}
# {'sentence': 'COCACOLA', 'cate': 'content', 'cate_conf': '0.90214896'}
# {'sentence': '20 .x 100,000 2,000,000', 'cate': 'content', 'cate_conf': '0.9993088'}
# {'sentence': 'HOA OUA', 'cate': 'info', 'cate_conf': '0.91877896'}
# {'sentence': '3x 2,000,000 6,000,000', 'cate': 'content', 'cate_conf': '0.99756193'}
# {'sentence': 'm,CỘNG 400,000,000', 'cate': 'content', 'cate_conf': '0.7532015'}
# {'sentence': 'KHACH TRA 400,000,000', 'cate': 'total', 'cate_conf': '0.9587341'}
# {'sentence': 'VND: 400,000,000', 'cate': 'content', 'cate_conf': '0.72596157'}
# {'sentence': 'CAM ON QUÝ KHAGH', 'cate': 'thank_you', 'cate_conf': '0.64392304'}
# {'sentence': 'HEN GAP LAL', 'cate': 'thank_you', 'cate_conf': '0.5169399'}
# {'sentence': '“> CAP MA 66 TPnNGI mm', 'cate': 'info', 'cate_conf': 0}
# {'sentence': '[', 'cate': 'total', 'cate_conf': 0}
# {'sentence': 'nà', 'cate': 'total', 'cate_conf': 0}
# {'sentence': 'Coffee Kem Sen Trang', 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': 'Đường Sá 2 - KDC 1385 - TT. Bên Lư', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'HÓA ĐƠN THANH TOÁN', 'cate': 'info', 'cate_conf': '0.9996686'}
# {'sentence': 'Hp: Doo6', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': 'Ngày 13/09/2017 Giờ  12:24:54', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'BAN: A1.', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'TÊN HÀNG SL ĐGIÁ T.TIỀN', 'cate': 'index', 'cate_conf': 1}
# {'sentence': 'Yaourt Nha Dam 1 25,000 25,000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Chanh Dây 4 20,000 20,000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Kem Socola 1 22,000 22,000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Kem Vanila 1 22,000 22,000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Kem Sầu Riêng 1 22,000 22,000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Kem Dừa 1 22,000 22,000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Nước Ép Ổi 1 28,000 28,000', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'Nước Ép Thơm 1 28,000 28,000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Nya', 'cate': 'total', 'cate_conf': 0}
# {'sentence': 'T.CONG 8 489,000', 'cate': 'total', 'cate_conf': '0.8186905'}
# {'sentence': 'GIAM % HB (-20%) -37,800', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'TIEN MAT 151,200', 'cate': 'total', 'cate_conf': '0.80331045'}
# {'sentence': 'Một trăm năm mươi mốt ngàn hai trăm', 'cate': 'total', 'cate_conf': '0.98742884'}
# {'sentence': 'đẳng./', 'cate': 'total', 'cate_conf': 0}
# {'sentence': 'BOON SENG PAPER SDN BHD (1248717-W)', 'cate': 'brand_name', 'cate_conf': '0.5292906'}
# {'sentence': '12, JALAN BUNGA TANJUNG,', 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': '2/16 SEKSYEN 2,', 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': '40000 SHAH ALAM, SELANGOR', 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': 'Tel :03-55190823 Fax: 03-55190823', 'cate': 'info', 'cate_conf': '0.99992037'}
# {'sentence': 'GST ID : 001005957120', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Tax Invoice', 'cate': 'info', 'cate_conf': '0.99993026'}
# {'sentence': 'No. :CS180319-0015', 'cate': 'thank_you', 'cate_conf': '0.50758934'}
# {'sentence': 'Qw RM Tax', 'cate': 'index', 'cate_conf': 1}
# {'sentence': '‘TAPE @ 2:50 12 30.00 SR', 'cate': 'total', 'cate_conf': '0.8015494'}
# {'sentence': "'Total Amtlncl.GST @ 6%: 31.80", 'cate': 'total', 'cate_conf': '0.7947673'}
# {'sentence': "Rounding Adjustment: 0:00'", 'cate': 'total', 'cate_conf': '0.9126078'}
# {'sentence': 'Total Amt Payable : 31.80', 'cate': 'total', 'cate_conf': '0.9247275'}
# {'sentence': 'Paid Amount: 31.80', 'cate': 'content', 'cate_conf': '0.53289205'}
# {'sentence': 'Change: 0.00', 'cate': 'total', 'cate_conf': '0.9289445'}
# {'sentence': 'Total Qty Tender : 12', 'cate': 'info', 'cate_conf': '0.99713814'}
# {'sentence': 'Deposit:', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': "'GSTSummay  Amount Tay", 'cate': 'total', 'cate_conf': '0.42500374'}
# {'sentence': 'ARM), RM)', 'cate': 'brand_name', 'cate_conf': '0.427073'}
# {'sentence': "'SR@6S% 3000 1807", 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': 'Tol... 80000 1 BO', 'cate': 'content', 'cate_conf': '0.9973603'}
# {'sentence': 'THANK YOU', 'cate': 'thank_you', 'cate_conf': '0.82910097'}
# {'sentence': "Goods Sold areinot'returnable", 'cate': 'thank_you', 'cate_conf': '0.6658361'}
# {'sentence': '19/03/2018 1:01:43PM', 'cate': 'info', 'cate_conf': '0.99747497'}
# {'sentence': '2.0', 'cate': 'brand_name', 'cate_conf': 0}
# {'sentence': '\\zieen', 'cate': 'total', 'cate_conf': 0}
# {'sentence': 'hing Gi Ton Theat', 'cate': 'info', 'cate_conf': 0}
# {'sentence': 'AZTEEN', 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': 'Tran Hung Bao - TT.Nam Sách - T.Hai Dương.', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Hotline: 0127.883.6789', 'cate': 'info', 'cate_conf': '0.99863213'}
# {'sentence': 'HÓA ĐƠN THANH TOÁN', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Ngày: 26/01⁄2018 Giờ: 11:40:19', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'BAN #', 'cate': 'info', 'cate_conf': '0.9920826'}
# {'sentence': 'Khách hàng:', 'cate': 'info', 'cate_conf': '0.50603986'}
# {'sentence': 'TÊN HÀNG. SL ĐGIÁ T.TIEN', 'cate': 'index', 'cate_conf': '0.9123054'}
# {'sentence': 'Trả sữa trà xanh. 1 19,000 19,000', 'cate': 'content', 'cate_conf': '1.0'}
# {'sentence': 'Pudding trứng 1 5,000 5,000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Thạch trái cây 1 5000 5,000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Trà sữa khoai môn 1 19,000 19,000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Thach trái cay 1 5,000  5,000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Thạch 3Q 1 5,000 5,000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'T.CỘNG 5 58,000', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'Tiên mặt 58,000', 'cate': 'total', 'cate_conf': '0.9674018'}
# {'sentence': 'Khách đưa 100,000.', 'cate': 'total', 'cate_conf': '0.9753121'}
# {'sentence': 'Trả lại 42,000', 'cate': 'total', 'cate_conf': '0.9603488'}
# {'sentence': 'XIN CẢM ƠN - HEN GAP LAI!', 'cate': 'thank_you', 'cate_conf': '0.9783627'}
# {'sentence': 'Pass wifi: 88888888', 'cate': 'info', 'cate_conf': '0.9977718'}
# {'sentence': '** BAN SAO HOA DON ****', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'SHOP TAN AN PHAT', 'cate': 'brand_name', 'cate_conf': '0.3727844'}
# {'sentence': '925/15 Âu Cơ -P. Tân Sơn Nhì - Q.Tan', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Phú - 08 6684 1111', 'cate': 'info', 'cate_conf': '0.9712842'}
# {'sentence': 'Phiếu Thanh Toán', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Khách hàng: Nguyễn Văn A -', 'cate': 'info', 'cate_conf': '0.9660521'}
# {'sentence': 'Số PTT: 00000066 Ngày: 13/01/15 - 11720', 'cate': 'info', 'cate_conf': '0.96852833'}
# {'sentence': 'Ca: 1 - Thu ngan: cashier', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Măt hàng SL. Dongid Thanh tien', 'cate': 'index', 'cate_conf': 1}
# {'sentence': 'nhan bo oil{ 4x 35,000 (10%) 31/500', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'nhan buom oil1 2x 35,000 (10%) 63,000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'nhẫn hoa oil nấm 1x 55,000 (10%) 49,500', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'nhãn nơ đai 1x 55,000-- (10%) 49,500', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'nhẫn rưa me cừng 2x 50,000 (10%) 90,00U', 'cate': 'content', 'cate_conf': '0.9899262'}
# {'sentence': 'con:', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'nhấn sao oil 4x 40,000 (10%) 26,000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Số lương:& tiền: 8 3 319,500', 'cate': 'total', 'cate_conf': '0.7647839'}
# {'sentence': 'Tiền khách trả: 319,500', 'cate': 'total', 'cate_conf': '0.95627165'}
# {'sentence': 'Tiền thừa: 0', 'cate': 'total', 'cate_conf': '0.69893324'}
# {'sentence': 'http://www.anphatshop.vn.', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': 'RESTORAN WAN SHENG', 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': '002043319-W', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Na.2, Jalan Temenggung 19/8,', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Saksyen 9, Bandar Mahkota Cheras,', 'cate': 'info', 'cate_conf': 1}
# {'sentence': '43200 Pheras, Se]angor', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'GST REG NO: 001335787520', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Tax Invoice', 'cate': 'info', 'cate_conf': '0.99993026'}
# {'sentence': 'INV No.: 1203856 Cashier: Nicole', 'cate': 'info', 'cate_conf': '0.8916585'}
# {'sentence': 'Date +: 21-06-2018 16:54:22', 'cate': 'info', 'cate_conf': '0.99993193'}
# {'sentence': 'Description Qty U.price Total TAX', 'cate': 'index', 'cate_conf': 1}
# {'sentence': 'Teh (Bì', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '1x 2.16 2,10 ZRL', 'cate': 'content', 'cate_conf': '0.94229704'}
# {'sentence': 'Chan (B)', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '1X 2.10 2,10 ZRL', 'cate': 'content', 'cate_conf': '0.9884659'}
# {'sentence': 'Take Away', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '2% 0,20 0.40 7RỊ.', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Total OTY: 4', 'cate': 'total', 'cate_conf': '0.96895164'}
# {'sentence': 'Total (Excluding GST): 4,60', 'cate': 'total', 'cate_conf': '0.592357'}
# {'sentence': '|. Total (Inclusive of GST); 4,60', 'cate': 'total', 'cate_conf': '0.592357'}
# {'sentence': 'TOTAL: 4.60', 'cate': 'total', 'cate_conf': 1}
# {'sentence': '| CASH : 4,80', 'cate': 'total', 'cate_conf': 1}
# {'sentence': '| GST Summary Amount(RM) — Tax(RM)', 'cate': 'index', 'cate_conf': 1}
# {'sentence': 'L/jRU (W0) 4680 0.00', 'cate': 'content', 'cate_conf': '0.96998006'}
# {'sentence': 'Hoa don', 'cate': 'info', 'cate_conf': 1}
# {'sentence': "BTENVENUE A L'ESSENTIEL", 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': '2016-05-05 19:01 No:0003 01-Cashier', 'cate': 'info', 'cate_conf': 1}
# {'sentence': '', 'cate': 'brand_name', 'cate_conf': 0}
# {'sentence': 'Ten menu Don gia So luong Tien', 'cate': 'index', 'cate_conf': 1}
# {'sentence': '—C - -—-— TT 7...0 ®œar', 'cate': 'total', 'cate_conf': 0}
# {'sentence': 'S1 Duck salad 150,000 1 150,000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'V{.Rib-eve steahk 380,000 1 590,906', 'cate': 'content', 'cate_conf': '0.9974589'}
# {'sentence': 'D2.(remeBrulae 100,000 1 160,000', 'cate': 'content', 'cate_conf': '0.9831029'}
# {'sentence': 'Barsalou 12.5cl 95,000. 1 95,000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Tien ban 735,000', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'Ten khong thue 735,000', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'Tien dich vu 36,000', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'Tong Cong 711.000', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'Tien 771,000', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'MERCI!', 'cate': 'thank_you', 'cate_conf': 1}
# {'sentence': 'ARENT OT', 'cate': 'thank_you', 'cate_conf': '0.8487227'}
# {'sentence': "Ran so ' 8B.", 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'POPULAR BOOK', 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': 'CO. (M) SDN BHD', 'cate': 'brand_name', 'cate_conf': '0.5232137'}
# {'sentence': '(Co. No. I13825-W)', 'cate': 'info', 'cate_conf': 1}
# {'sentence': '(GST Reg No. 001492992000)', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'No 8, Jalan 771188, Desa Tun lazak', 'cate': 'info', 'cate_conf': '0.87695575'}
# {'sentence': '56000 Kuala Lumpur, Malaysia', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'EMPIRE SHOPPING GALLERY', 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': 'Tel : 03-56319320', 'cate': 'info', 'cate_conf': '0.99894387'}
# {'sentence': '(05/03/18 15:02 Slip No.: 1010104759', 'cate': 'info', 'cate_conf': '0.8732254'}
# {'sentence': 'Li Fong Trans: 104610', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Member Card No: 1001016668849', 'cate': 'info', 'cate_conf': '0.82934'}
# {'sentence': 'Card Expiry: 31/05/18', 'cate': 'info', 'cate_conf': '0.99922895'}
# {'sentence': 'eseripLion Amount', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': 'SŒ Aer Frane 5103M', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': '2pc ® 5.50 11.00 T', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Member Discount “1.10', 'cate': 'info', 'cate_conf': '0.9962831'}
# {'sentence': 'Total RM fncl. of GST 9.90', 'cate': 'total', 'cate_conf': '0.8314112'}
# {'sentence': 'Cash ~20.00', 'cate': 'total', 'cate_conf': '0.95456064'}
# {'sentence': 'CHANGE 10.10', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'Item Count Š : độ', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'GST) Summary Amount (RM)  Tax (RM}', 'cate': 'info', 'cate_conf': '0.96316934'}
# {'sentence': 'T @ 6% 9.34 0.56', 'cate': 'total', 'cate_conf': '0.5746698'}
# {'sentence': 'Total Savings -1,.10:', 'cate': 'total', 'cate_conf': '0.96384996'}
# {'sentence': 'BE A POPULAR CARD MEMBER', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'AND ENJOY SPECIAL DISCOUNTS', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': 'THANK YOU. PLEASE COME AGAIN.', 'cate': 'thank_you', 'cate_conf': '0.9580079'}
# {'sentence': 'wWwWW..popuiar. com. my', 'cate': 'brand_name', 'cate_conf': '0.4953919'}
# {'sentence': 'Buy Chinese books. onl ine', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': 'www. Popularonline.com. ny.', 'cate': 'brand_name', 'cate_conf': '0.4953919'}
# {'sentence': 'PANDAH INDAH PULAU KETAM RESTAURANT', 'cate': 'brand_name', 'cate_conf': '0.3432127'}
# {'sentence': 'M4-A-B, JALAN PANDAH INDAH 4/1A,', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'PANDAH INDAH, 55100 KUALA LUMPUR.', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'TEL:012-2673122 / 010-2022283', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'GUEST CHECK', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Table 6', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Check #: 113355 Pax(s): 0', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Date ; 30-04-2018 18:50:14', 'cate': 'info', 'cate_conf': '0.8820886'}
# {'sentence': 'Server : CASHIER', 'cate': 'info', 'cate_conf': '0.9681531'}
# {'sentence': 'KUO POH (C) (2 PAX) 6.00', 'cate': 'total', 'cate_conf': 1}
# {'sentence': '2T EA EXTRA PERSON (1 PAX) 2.00', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'TONG HOU 10,00', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'MUTTAN SLICE 15,00', 'cate': 'content', 'cate_conf': '0.92779124'}
# {'sentence': 'SOUP 0.00', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'T0M YUM 0,00', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '| 3 NO. OF HEAD (2 SET ABOVE) 60.00', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '| Subtotal : 93.00', 'cate': 'total', 'cate_conf': '0.84923714'}
# {'sentence': '| TOTAL: 93.00', 'cate': 'total', 'cate_conf': '0.9786228'}
# {'sentence': '‘Svanen as cnas op sberanesanenanancsenausa', 'cate': 'total', 'cate_conf': 0}
# {'sentence': 'HOW MWA HARDWARE TRADING', 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': 'Company Reg. Na. ; 00105513934X', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'NO 37, JALAN MANIS 7, TAMAN SEGAR,', 'cate': 'info', 'cate_conf': '0.9890098'}
# {'sentence': '56100 CHERAS, KUALA LUMPUR.', 'cate': 'info', 'cate_conf': 1}
# {'sentence': '+604-3140 2674', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'GST Reg : 001125220352', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'TAX INVOICE', 'cate': 'info', 'cate_conf': '0.99993026'}
# {'sentence': 'CB: 87870 21/09/2017 10:20:37 AM', 'cate': 'info', 'cate_conf': '0.9956409'}
# {'sentence': 'k## - Œ2-0', 'cate': 'info', 'cate_conf': '0.30173048'}
# {'sentence': 'Cashier cash1+.', 'cate': 'info', 'cate_conf': '0.9681531'}
# {'sentence': 'Qty Description Price Total(Rivt,', 'cate': 'brand_name', 'cate_conf': '0.26975083'}
# {'sentence': '0. 3/4" ALUMINIUM ROD 6.00 5.40 SR', 'cate': 'content', 'cate_conf': '0.85719895'}
# {'sentence': '5 PVO WALLPLUG 100 5.00 Sl\\', 'cate': 'content', 'cate_conf': '0.9855338'}
# {'sentence': '(50PCS)', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': '5.9 Type: 2 Total 10.40', 'cate': 'total', 'cate_conf': '0.9325883'}
# {'sentence': 'Discount: 0.00', 'cate': 'total', 'cate_conf': '0.8826262'}
# {'sentence': 'Rounding Adj 0.00', 'cate': 'total', 'cate_conf': '0.9393576'}
# {'sentence': 'Total Inclusive GST: 10.40', 'cate': 'total', 'cate_conf': '0.51067823'}
# {'sentence': 'CASH 40.40', 'cate': 'info', 'cate_conf': '0.6575983'}
# {'sentence': 'GST Surnrrrary', 'cate': 'total', 'cate_conf': '0.5571397'}
# {'sentence': 'Code % NetAmt  GST TofalWM)', 'cate': 'brand_name', 'cate_conf': '0.51650965'}
# {'sentence': 'SR SR 981 £049 1040', 'cate': 'info', 'cate_conf': '0.9924234'}
# {'sentence': 'Total 981 0.59 40.40', 'cate': 'total', 'cate_conf': '0.81166184'}
# {'sentence': 'Thank you | & Please come again II', 'cate': 'thank_you', 'cate_conf': '0.9580079'}
# {'sentence': 'Goods sald are nol returnable for refund or exchange II', 'cate': 'thank_you', 'cate_conf': '0.82063234'}
# {'sentence': 'Tao QUẦN NHẬU BÌNH DẪN 120', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Uỳnh Tấn Phát - Hai Chấu - Địi Nông', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'PHIẾU THANH TOÁN', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Sð phiếu: g2aa _', 'cate': 'info', 'cate_conf': '0.995194'}
# {'sentence': '', 'cate': '', 'cate_conf': '0'}
# {'sentence': 'Tiger nau ˆ', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '4000 —_— 56/006.', 'cate': 'content', 'cate_conf': '0.46149173'}
# {'sentence': 'Bánh trắng', 'cate': 'content', 'cate_conf': '0.7029505'}
# {'sentence': '30000.0 9.0', 'cate': 'total', 'cate_conf': '0.7728715'}
# {'sentence': '"Cá Lác chiến mắm Xoài.', 'cate': 'total', 'cate_conf': '0.40888593'}
# {'sentence': '_ 60,008. 60.000', 'cate': 'content', 'cate_conf': '0.9993043'}
# {'sentence': '35,000 35.000', 'cate': 'total', 'cate_conf': '0.9310128'}
# {'sentence': '-Hẽn xảo.', 'cate': 'content', 'cate_conf': '0.6540947'}
# {'sentence': '_Ò 12000 12,000', 'cate': 'total', 'cate_conf': '0.9708962'}
# {'sentence': '"Khoal tay chia”', 'cate': 'total', 'cate_conf': '0.42500374'}
# {'sentence': '„„j5/000 _ _ 15.000', 'cate': 'content', 'cate_conf': '0.99480647'}
# {'sentence': '"BĂp non xảo ˆ', 'cate': 'total', 'cate_conf': '0.5343699'}
# {'sentence': 'tr __ 15.000.', 'cate': 'content', 'cate_conf': '0.9702314'}
# {'sentence': '"Nưäc ngọt chal', 'cate': 'content', 'cate_conf': '0.6594385'}
# {'sentence': '_ 16.000.', 'cate': 'total', 'cate_conf': '0.9818163'}
# {'sentence': '“Nưếc suối.', 'cate': 'content', 'cate_conf': '0.6496346'}
# {'sentence': 'TA —_ 8/000.', 'cate': 'content', 'cate_conf': '0.9660779'}
# {'sentence': '"TT sụn Gà chiên mạm  ~', 'cate': 'content', 'cate_conf': '0.9972921'}
# {'sentence': '', 'cate': 'content', 'cate_conf': 0}
# {'sentence': '', 'cate': 'brand_name', 'cate_conf': 0}
# {'sentence': '', 'cate': 'brand_name', 'cate_conf': 0}
# {'sentence': '_“J.0n0_', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': '----35,000', 'cate': 'total', 'cate_conf': '0.9312553'}
# {'sentence': '', 'cate': 'brand_name', 'cate_conf': 0}
# {'sentence': '“E000', 'cate': 'total', 'cate_conf': 0}
# {'sentence': '', 'cate': 'brand_name', 'cate_conf': 0}
# {'sentence': 'Thanh toán. F', 'cate': 'total', 'cate_conf': 1}
# {'sentence': '', 'cate': 'brand_name', 'cate_conf': 0}
# {'sentence': '(Cam on và Vi Suý khách', 'cate': 'thank_you', 'cate_conf': '0.924215'}
# {'sentence': "È'03/21770", 'cate': 'total', 'cate_conf': 0}
# {'sentence': 'RESTORAN WAN SHENG', 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': '002043319-W', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'No.2, Jalan Temenggung 19/9,', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Seksyen 9, Bandar Mahkota Cheras,', 'cate': 'info', 'cate_conf': 1}
# {'sentence': '43200 Cheras, Selangor', 'cate': 'info', 'cate_conf': '0.8878318'}
# {'sentence': 'GST REG NO: 001335787520', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Tax Invoice', 'cate': 'info', 'cate_conf': '0.99993026'}
# {'sentence': 'INV Ho.: 1169924 Cashier: Thandar', 'cate': 'info', 'cate_conf': '0.9681531'}
# {'sentence': 'fate  : 01-08-2018 14:20:08', 'cate': 'info', 'cate_conf': '0.99886787'}
# {'sentence': 'Oescription Qty  U.price Total TAX', 'cate': 'index', 'cate_conf': 1}
# {'sentence': 'Teh (Bì', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '2% 2.20 4.40 7RL', 'cate': 'content', 'cate_conf': '0.95460874'}
# {'sentence': 'Take Away', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '2x 0.20 0.40 ZRL', 'cate': 'total', 'cate_conf': '0.8119399'}
# {'sentence': 'Total Gfy: 4', 'cate': 'total', 'cate_conf': '0.96895164'}
# {'sentence': 'Total (Excluding GST): 4.80', 'cate': 'content', 'cate_conf': '0.79683334'}
# {'sentence': 'Total -(Inelusive of GST): 4,80', 'cate': 'content', 'cate_conf': '0.79683334'}
# {'sentence': 'TOTAL: 4.80', 'cate': 'content', 'cate_conf': '0.8919497'}
# {'sentence': 'CASH : 4,80', 'cate': 'total', 'cate_conf': 1}
# {'sentence': '65T 8utinary Anlount(RM)  Tax(RM})', 'cate': 'index', 'cate_conf': 1}
# {'sentence': 'HH (@ 0%) 4.80 0.00', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'LIKE CAFE', 'cate': 'brand_name', 'cate_conf': '0.59381646'}
# {'sentence': 'Số 10 Khúc Hạo, Ba Đình, Hà Nội', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'U46297419279:', 'cate': 'total', 'cate_conf': 0}
# {'sentence': 'HOA ĐƠN THANH TOÁN.', 'cate': 'info', 'cate_conf': '0.99795973'}
# {'sentence': 'HOĐIOÓA114-46', 'cate': 'total', 'cate_conf': 0}
# {'sentence': 'Bàn01 ` 19/01/2014 8:49:59H ˆ', 'cate': 'info', 'cate_conf': '0.9902164'}
# {'sentence': 'STT Thực đơn ĐVT Đơn Giá SL Thành Tiền', 'cate': 'index', 'cate_conf': 1}
# {'sentence': 'Bạc sửu 1 cốc 100.000 1 100.000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Cà phê nâu* 1 cốc 100.000 1 100.000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Hướng dường (cuối tuần) Đĩa 55.000 1 55.000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Sữa tươi 1 cốc 100.000 1 100.000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Trà bạc hà 1 cốc 95.000 1 95.000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Vinntaba Chai 90.000 1 90.000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Tiền hàng', 'cate': 'total', 'cate_conf': 1}
# {'sentence': '540.000', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'Giảm gìá; - 0%', 'cate': 'total', 'cate_conf': '0.92869925'}
# {'sentence': 'Og', 'cate': 'total', 'cate_conf': 0}
# {'sentence': 'Tổng trên thanh toán::', 'cate': 'total', 'cate_conf': '0.9743353'}
# {'sentence': '540.000đ', 'cate': 'total', 'cate_conf': '0.96954805'}
# {'sentence': 'Xin chân thành cám ơn quý khách! Hẹn gặp lại!', 'cate': 'thank_you', 'cate_conf': 1}
# {'sentence': 'QUAN AN THIEN TÂN |', 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': '17-19 TON DAN F13Q4 TPHCM', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'DT: 9407863-8259956', 'cate': 'info', 'cate_conf': '0.99844897'}
# {'sentence': 'REG 13-11-2011 20:54', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'CA 1 MC #01 00098/', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'BANSO: 47', 'cate': 'info', 'cate_conf': '0.9994174'}
# {'sentence': '1 BUN SING 42,000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'MI GION X CHAY 37,000', 'cate': 'content', 'cate_conf': '0.9999119'}
# {'sentence': '2 MI X GION N 80, 000', 'cate': 'content', 'cate_conf': '0.99999714'}
# {'sentence': '4 COM BAT BUU 172, 00U', 'cate': 'content', 'cate_conf': '0.9999131'}
# {'sentence': 'SUON CHIEN KDO 65,000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'HU TIEU N 40, 000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'TOM LAN BOT 65,000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '2 PEFSI 16,000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '10 TRA DA 20, O00', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'TIEN MAT', 'cate': 'total', 'cate_conf': 1}
# {'sentence': '537.0', 'cate': 'info', 'cate_conf': 0}
# {'sentence': 'CAM ON QUY KHACH', 'cate': 'thank_you', 'cate_conf': 1}
# {'sentence': 'HEN GAP LAI!', 'cate': 'thank_you', 'cate_conf': '0.9256481'}
# {'sentence': 'ONE ONE THREE SEAFOOD RESTAURANT SDN BHD', 'cate': 'brand_name', 'cate_conf': '0.62682587'}
# {'sentence': "'1120908-M)", 'cate': 'total', 'cate_conf': 0}
# {'sentence': 'NO.1, TaMAN SRI DENGKIL, JALAN AIR HITAM', 'cate': 'info', 'cate_conf': 1}
# {'sentence': '43800 DENGKIL, SELANGDR.', 'cate': 'info', 'cate_conf': 1}
# {'sentence': '(ST Reg. No : 000670224384)', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Tax Invoice', 'cate': 'info', 'cate_conf': '0.99993026'}
# {'sentence': 'Table 23.', 'cate': 'info', 'cate_conf': '0.6919964'}
# {'sentence': '8i11# -V001-541021 0rder#; 141128', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Date  : 23-06-2018 20:52:18', 'cate': 'info', 'cate_conf': '0.9998646'}
# {'sentence': 'Cashier: 113 CASHIER Pax(s): 0', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Qty  Description Total TAX', 'cate': 'index', 'cate_conf': 1}
# {'sentence': 'D 30.00 SR', 'cate': 'content', 'cate_conf': '0.80943596'}
# {'sentence': 'Van Tten', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'D 30.00 §R', 'cate': 'content', 'cate_conf': '0.9858395'}
# {'sentence': 'S.Soup lala Item (XL)', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'D 77.00 SR', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Fish Item', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '15.00 SR', 'cate': 'total', 'cate_conf': '0.76679546'}
# {'sentence': 'Omellete Item', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'D 7.50 SR', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'white Rice', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'D 15.00 SR', 'cate': 'total', 'cate_conf': '0.76679546'}
# {'sentence': 'Vege Item (M)', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'D 6.00 SR', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Beverage', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Total (Excluding GST): 179.50', 'cate': 'total', 'cate_conf': '0.9740269'}
# {'sentence': 'Total (inclusive of GST): 179.50', 'cate': 'total', 'cate_conf': '0.9740269'}
# {'sentence': 'TOTAL: 179.50', 'cate': 'total', 'cate_conf': '0.9645148'}
# {'sentence': 'Closed: 1 23-06-2010 21:29:23', 'cate': 'info', 'cate_conf': '0.9833387'}
# {'sentence': 'Server: 113 CASHIER', 'cate': 'info', 'cate_conf': '0.9681531'}
# {'sentence': 'CASH : 179,50', 'cate': 'info', 'cate_conf': '0.66099185'}
# {'sentence': 'GST Sumaary Amount(RM)  Tax(RM)', 'cate': 'info', 'cate_conf': '0.9613026'}
# {'sentence': '§E (60%) 17950 0.00', 'cate': 'content', 'cate_conf': '0.7374553'}
# {'sentence': 't+ Thank You ##‡*', 'cate': 'thank_you', 'cate_conf': '0.6353155'}
# {'sentence': 'Please Come Again', 'cate': 'thank_you', 'cate_conf': '0.93540907'}
# {'sentence': 'RESTORAN WAN SHENG', 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': '002043319-W', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'No.2, Jalan Temenggung 19/9,', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Seksyen 9, Bandar Mahkota Cheras,', 'cate': 'info', 'cate_conf': 1}
# {'sentence': '43200 Cheras, Selangor', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'GST REG NO: 001335787520', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Tax Invoice', 'cate': 'info', 'cate_conf': '0.99993026'}
# {'sentence': 'INV No.: 1216991 Cashier: Nicole', 'cate': 'info', 'cate_conf': '0.8916585'}
# {'sentence': 'Date : 29-06-2018 16:13:05', 'cate': 'info', 'cate_conf': '0.9999895'}
# {'sentence': 'Description Qty  U.price Tota? TAX', 'cate': 'info', 'cate_conf': '0.7202065'}
# {'sentence': 'Kopi 0 (ñ)', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '1x 2,00 2.00 ZRL', 'cate': 'content', 'cate_conf': '0.99923074'}
# {'sentence': 'Pham (Rì', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '1x 2.10 2.10 ZRI.', 'cate': 'content', 'cate_conf': '0.9884659'}
# {'sentence': 'Nescafe (B)', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '1x 2,50 2,b0 7RL', 'cate': 'content', 'cate_conf': '0.9989202'}
# {'sentence': 'Take Auavw', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '3x 0,20 0.80 7RL', 'cate': 'content', 'cate_conf': '0.9434384'}
# {'sentence': 'Total QTY: 6', 'cate': 'total', 'cate_conf': '0.9416355'}
# {'sentence': 'Yotal (Excluding GST): 7.20', 'cate': 'total', 'cate_conf': '0.9572947'}
# {'sentence': 'Total (Inclusive of GST); 7.20', 'cate': 'total', 'cate_conf': '0.9809942'}
# {'sentence': 'TOTAL : 7.20', 'cate': 'total', 'cate_conf': '0.9777754'}
# {'sentence': 'CASH 3 7.20', 'cate': 'total', 'cate_conf': '0.92971814'}
# {'sentence': 'GST Summary — — Amount(RM) Tax(RM)', 'cate': 'index', 'cate_conf': 1}
# {'sentence': 'JRLU .. (0. - 720 0.00', 'cate': 'content', 'cate_conf': '0.5783114'}
# {'sentence': '‘ansican', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': "Korea's coliee", 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': "FANSIPAN KOREA'S", 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': 'GOFFEE', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': '883A ÂU CƠ-P. TÂN THÀNH-Q TAN PHO', 'cate': 'index', 'cate_conf': '0.54230446'}
# {'sentence': 'Tel’ 08 6 269 3597', 'cate': 'total', 'cate_conf': '0.85707605'}
# {'sentence': 'HÓA ĐƠN THANH TOÁN', 'cate': 'info', 'cate_conf': '0.9996686'}
# {'sentence': 'SáTT 0008', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': 'Ngày vào 23112015 Gi@ vào: 124727', 'cate': 'info', 'cate_conf': '0.9994429'}
# {'sentence': 'Ngày: — 23/12015 Giờ 1424727', 'cate': 'info', 'cate_conf': '0.999556'}
# {'sentence': 'Ban: TRET1', 'cate': 'info', 'cate_conf': '0.9920826'}
# {'sentence': 'TÊN HÀNG st oa Y.TIẾM', 'cate': 'info', 'cate_conf': '0.41435194'}
# {'sentence': 'CA PHÉ SỮA ĐÁ 20 35000 70000', 'cate': 'content', 'cate_conf': '0.9998667'}
# {'sentence': 'CA PHE ĐEN 1.0 25.000 25.000', 'cate': 'content', 'cate_conf': '0.99666506'}
# {'sentence': 'T.CONG 3.0 95.000', 'cate': 'total', 'cate_conf': '0.9294127'}
# {'sentence': 'TIÊN MẶT 95,000', 'cate': 'total', 'cate_conf': '0.7673367'}
# {'sentence': 'Chin muoi lim ngan dong /.', 'cate': 'total', 'cate_conf': '0.9268094'}
# {'sentence': 'XIN CAM ON- HEN GAP LAI', 'cate': 'thank_you', 'cate_conf': '0.9687793'}
# {'sentence': 'HOTLINE: 0984.087.24', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'PUDADAC', 'cate': 'brand_name', 'cate_conf': '0.58769405'}
# {'sentence': 'A19 - Home Clly- Trung Kinh- Câu Giáy - HN', 'cate': 'info', 'cate_conf': '0.999134'}
# {'sentence': '904.0 926.0 577.0', 'cate': 'info', 'cate_conf': '0.990128'}
# {'sentence': 'HÓA ĐƠN THANH TOÁN', 'cate': 'info', 'cate_conf': '0.9996686'}
# {'sentence': 'HĐ: 0006', 'cate': 'info', 'cate_conf': '0.9920288'}
# {'sentence': 'Ngày: 18/06/2017 Giờ: 13:40:24', 'cate': 'info', 'cate_conf': '0.99897975'}
# {'sentence': 'Hé', 'cate': 'info', 'cate_conf': '0.39719048'}
# {'sentence': 'Thu ngân: Người quản trị', 'cate': 'info', 'cate_conf': '0.99948454'}
# {'sentence': 'Khách hàng', 'cate': 'info', 'cate_conf': '0.50603986'}
# {'sentence': 'TEN HANG SL ĐG T.TIỀN', 'cate': 'index', 'cate_conf': '0.9594317'}
# {'sentence': 'THỨC ĂN', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Gà rán sốt xì dầu 1.0 260,000 260,000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Gà rán sắt tỏi 4.0 260,000 260,000', 'cate': 'content', 'cate_conf': '0.9999994'}
# {'sentence': 'Cơm cuộn cá ngừ 1.0 60,000 60,000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '680,000', 'cate': 'total', 'cate_conf': 0}
# {'sentence': 'THỨC UỐNG', 'cate': 'index', 'cate_conf': 1}
# {'sentence': 'Nước ép chanh dây: 1.0 45,000 45,000', 'cate': 'content', 'cate_conf': '0.99999976'}
# {'sentence': 'Nước áp cả rốt+ cà 1.0 60,000 50,000', 'cate': 'content', 'cate_conf': '0.9999999'}
# {'sentence': 'chua', 'cate': 'brand_name', 'cate_conf': 0}
# {'sentence': '95,000', 'cate': 'total', 'cate_conf': 0}
# {'sentence': 'T.CONG 5.0 676,000', 'cate': 'total', 'cate_conf': '0.967139'}
# {'sentence': 'TIÊN MẠT 675,000', 'cate': 'total', 'cate_conf': '0.9717585'}
# {'sentence': 'Sáu trăm bảy mươi lăm ngàn đồng,/.', 'cate': 'total', 'cate_conf': '0.9799447'}
# {'sentence': 'KHÁCH ĐƯA 700,000', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'TRẢ LẠI 25,000', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'XIN CAM ON - HEN GAP LAI', 'cate': 'thank_you', 'cate_conf': '0.9687793'}
# {'sentence': '**“** BẠN SAO HOA DON **', 'cate': 'thank_you', 'cate_conf': '0.9281141'}
# {'sentence': 'FISH FARM THA! RESTAURANT', 'cate': 'brand_name', 'cate_conf': '0.5555917'}
# {'sentence': 'Veg Fish Farm Thai Restaurant S/B', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'mp. Re3. Ne. 926627-V', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'KM 4, Jin Ampang, Hulu Langat,', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'G8000 Amapny, Selangor.', 'cate': 'info', 'cate_conf': 1}
# {'sentence': '(601 2-2€0 6493 or +6012-286 8193', 'cate': 'info', 'cate_conf': 1}
# {'sentence': '“TAX INVOICE***', 'cate': 'info', 'cate_conf': '0.9979962'}
# {'sentence': 'GST Reg. No.: 0008 3385 3536', 'cate': 'info', 'cate_conf': 1}
# {'sentence': '(DUFLICATED)', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Hat CLOSE on , BỤẾA 2018 náo sz', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Table 40  Pax 6 -', 'cate': 'index', 'cate_conf': 1}
# {'sentence': 'Cashier: jam02 01/05/2018 2:30:10', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Qty ProductCode UnitRM SubtotalRM &TaxCode', 'cate': 'index', 'cate_conf': 1}
# {'sentence': 'Description', 'cate': 'info', 'cate_conf': 1}
# {'sentence': '80.00 80.00 SR', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'FRIED KAWPUNG CHICKEN (1 EKOR).', 'cate': 'content', 'cate_conf': '0.5953479'}
# {'sentence': '40.00 40.00 SR.', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'TORIYAM SEAI7OCD (MERAH)', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'PGE 2000 20.01 SR', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'WATERMELON JUICE (BIG)', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Fan 2000 2000 SR.', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'ORANGE JUICE /BIG)', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '21.00 21.00 SR', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'LALA GIILI ĐASTE (BỊ', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '380 1500 SR.', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'MASI PUTIM,', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '84.00 8400 SR', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '‘BBO TALAPIA.', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '36.00 3900 SR', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'SOTONG STEAM LIME SAUCE', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '€ựpạo, 15.00 800 SR', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'KACANS BOTOL B.PUTIH (B)', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'T2B 1200 12.00 SR', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'TELUR. GORENG BAWANG (8)', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '36.00 2800 SR', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'BUTTER PRAWN (13),', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'SUBTOTAL: 371.00', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'NẸT SAILIS  : 371.00', 'cate': 'total', 'cate_conf': '0.84923714'}
# {'sentence': '§SERVICE CHARGE 5X : 18,58', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'ST 0M CC 04 ag', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'Total 412.92', 'cate': 'total', 'cate_conf': '0.6934459'}
# {'sentence': 'Rounding Adj. : 0.02,', 'cate': 'total', 'cate_conf': '0.595518'}
# {'sentence': 'GRAND TOTAL: 412.80', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'VISA 412.90', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'GST CODE & %: Amount (RM): Tax (RM):', 'cate': 'index', 'cate_conf': 1}
# {'sentence': 'cre oA,', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': 'S6955 23.37', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'ZRL 0% A00 000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Thank You!', 'cate': 'thank_you', 'cate_conf': '0.82910097'}
# {'sentence': 'Gid £a;2014-16-17 Ó1:015/', 'cate': 'info', 'cate_conf': 0}
# {'sentence': '20 IN', 'cate': 'info', 'cate_conf': 0}
# {'sentence': 'HĐ;BH:20141017.006 HĐB;18.20141016.0001', 'cate': 'info', 'cate_conf': '0.926792'}
# {'sentence': 'PHIẾU THANH TOÁN.', 'cate': 'info', 'cate_conf': '0.9992262'}
# {'sentence': 'Stt Sản phầm. SL Digia T.tien', 'cate': 'index', 'cate_conf': '0.8054659'}
# {'sentence': 'Chanh tươi 1 80,000. 80,600', 'cate': 'content', 'cate_conf': '0.9999989'}
# {'sentence': 'Chivas 38 6 26,900,000 161,400,000', 'cate': 'total', 'cate_conf': '0.9593543'}
# {'sentence': 'Hoa qua dic biét 2 $00,000 1,999,009.', 'cate': 'content', 'cate_conf': '0.9542973'}
# {'sentence': 'Lavie: 22 65,000: 1,430,000.', 'cate': 'content', 'cate_conf': '0.98687255'}
# {'sentence': 'Shisha vip, 2 500,000 1,000,000', 'cate': 'content', 'cate_conf': '0.9992895'}
# {'sentence': 'Chivas 38', 'cate': 'info', 'cate_conf': 0}
# {'sentence': 'Coke 4 65,000 260,000:', 'cate': 'content', 'cate_conf': 1}
# ...
# {'sentence': 'Rounding Adjustment:', 'cate': 'total', 'cate_conf': '0.9495394'}
# {'sentence': "'Total Amt Payable : 12.00", 'cate': 'total', 'cate_conf': '0.8245537'}
# {'sentence': 'Paid Amount 20.00', 'cate': 'total', 'cate_conf': '0.8077414'}
# {'sentence': 'Change: 8.00', 'cate': 'total', 'cate_conf': '0.53623295'}
# {'sentence': 'Total Qty Tender :', 'cate': 'total', 'cate_conf': '0.8280037'}
# {'sentence': '‘GST Summary Amount Tax ', 'cate': 'total', 'cate_conf': 1}
# {'sentence': '(RM) (RM) :', 'cate': 'brand_name', 'cate_conf': 0}
# {'sentence': 'SR @ A  11.32  068:', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'Total  11.32  0.68 :', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'THANK YOU', 'cate': 'thank_you', 'cate_conf': '0.82910097'}
# {'sentence': 'For any enquiry, please contact us:', 'cate': 'thank_you', 'cate_conf': 1}
# {'sentence': 'THE OPERA', 'cate': 'brand_name', 'cate_conf': '0.63211024'}
# {'sentence': 'Sá 1 Trưng Yên 3 - Ngõ 67 Nguyễm', 'cate': 'info', 'cate_conf': '0.99486274'}
# {'sentence': 'Khang - Cều Giây - HN', 'cate': 'info', 'cate_conf': '0.99912256'}
# {'sentence': '0982 434 830', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'HÓA ĐƠN THANH TOAN', 'cate': 'info', 'cate_conf': '0.9997855'}
# {'sentence': 'SóHĐ 0002', 'cate': 'info', 'cate_conf': '0.9996556'}
# {'sentence': 'Ngày: 30/05/2017 Giờ 10:26:13', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'TakeAway', 'cate': 'info', 'cate_conf': '0.98428845'}
# {'sentence': 'Thu ngân: Người quản trị', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Khách hàng:', 'cate': 'info', 'cate_conf': '0.50603986'}
# {'sentence': 'TÊN HÀNG SL ĐG T.TIÊN', 'cate': 'index', 'cate_conf': 1}
# {'sentence': 'THỨC UỎNG', 'cate': 'index', 'cate_conf': 1}
# {'sentence': 'Trà sữa Khoai 1 23,000', 'cate': 'content', 'cate_conf': '0.9999951'}
# {'sentence': 'môn-M', 'cate': 'content', 'cate_conf': 0}
# {'sentence': '|->Trân châu 1 5.000', 'cate': 'content', 'cate_conf': '0.99127674'}
# {'sentence': 'đen', 'cate': 'content', 'cate_conf': '0.9066954'}
# {'sentence': '|->Thạch rau 1 5.000', 'cate': 'content', 'cate_conf': '0.997329'}
# {'sentence': 'câu', 'cate': 'content', 'cate_conf': '0.91945183'}
# {'sentence': 'Tra xanh tao-L 1 28,000', 'cate': 'content', 'cate_conf': '0.9988826'}
# {'sentence': 'Trà dưa lưới-L 1 28000', 'cate': 'content', 'cate_conf': '0.9999994'}
# {'sentence': '89,000', 'cate': 'content', 'cate_conf': '0.5048292'}
# {'sentence': 'T.CONG 89,000', 'cate': 'total', 'cate_conf': '0.9325786'}
# {'sentence': 'TIEN MAT 89,000', 'cate': 'total', 'cate_conf': '0.92135346'}
# {'sentence': 'Tám mươi chín ngàn đẳng. /.', 'cate': 'total', 'cate_conf': '0.9735908'}
# {'sentence': 'XIN CAM ON - HEN GAP LAI', 'cate': 'thank_you', 'cate_conf': 1}
# {'sentence': "BILL HOA DO'N KHO 8CM", 'cate': 'info', 'cate_conf': '0.9995633'}
# {'sentence': 'MR.BOOM', 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': 'Đ/C: KĐT Sinh Thái Cao Cáp', 'cate': 'info', 'cate_conf': '0.99605197'}
# {'sentence': 'Đan Phượng - Hà Nội -', 'cate': 'info', 'cate_conf': '0.99844736'}
# {'sentence': '09144622222 -', 'cate': 'info', 'cate_conf': '0.9869006'}
# {'sentence': 'HÓA ĐƠN THANH TOÁN', 'cate': 'info', 'cate_conf': '0.9996686'}
# {'sentence': 'HĐ: 0003', 'cate': 'info', 'cate_conf': '0.99891114'}
# {'sentence': 'Ngày: 20/04/2018 Giờ: 16:05:09', 'cate': 'info', 'cate_conf': '0.9999912'}
# {'sentence': 'BANS 12', 'cate': 'info', 'cate_conf': '0.9988009'}
# {'sentence': 'TÊN HÀNG SL ĐGIÁ T.TIÊN', 'cate': 'index', 'cate_conf': 1}
# {'sentence': 'Thúc ăn', 'cate': 'content', 'cate_conf': '0.99071807'}
# {'sentence': '2. Cảnh gà chiên 1 34,000 34,000', 'cate': 'content', 'cate_conf': '0.9999999'}
# {'sentence': 'giòn cav -', 'cate': 'content', 'cate_conf': '0.9963858'}
# {'sentence': '18. Xúc xÍehchiên 1 15,000 15,000', 'cate': 'content', 'cate_conf': '0.9999436'}
# {'sentence': '18.Khoaitiylắ€c 1 17.000 17,000', 'cate': 'content', 'cate_conf': '0.99906904'}
# {'sentence': 'Comboi 1 79/000 79,000', 'cate': 'content', 'cate_conf': '0.99998975'}
# {'sentence': 'Đùi gà giòn cay', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'uv', 'cate': 'content', 'cate_conf': 0}
# {'sentence': 'Cánh gà giòn', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'cay', 'cate': 'total', 'cate_conf': 0}
# {'sentence': 'Khoai tây chiên', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'l->Cocacola', 'cate': 'content', 'cate_conf': '0.999368'}
# {'sentence': 'Combo2 1 75,000 75,000', 'cate': 'content', 'cate_conf': '0.999995'}
# {'sentence': '|->Gà quay gidy', 'cate': 'content', 'cate_conf': '0.99964094'}
# {'sentence': 'bac', 'cate': 'content', 'cate_conf': '0.9582949'}
# {'sentence': 'Khoail tây chiên.', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Cocacola', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '220,000', 'cate': 'total', 'cate_conf': 0}
# {'sentence': 'T.CONG 12 220,000', 'cate': 'total', 'cate_conf': '0.9912348'}
# {'sentence': 'GIAM % HB (-5%) -11,000', 'cate': 'total', 'cate_conf': '0.96908927'}
# {'sentence': 'Tiên mặt 209,000', 'cate': 'total', 'cate_conf': '0.9514627'}
# {'sentence': 'Khách đưa 800,00', 'cate': 'total', 'cate_conf': '0.98010343'}
# {'sentence': 'Trả lại 291,000', 'cate': 'total', 'cate_conf': '0.9450362'}
# {'sentence': 'CÀM ƠN QUY KHÁCH', 'cate': 'thank_you', 'cate_conf': '0.92807424'}
# {'sentence': 'HEN GAP LAI!', 'cate': 'thank_you', 'cate_conf': '0.9256481'}
# {'sentence': 'BIDA', 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': 'Bida Phuong Hoang', 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': 'Thanh Phố Mới - BÌnh Dương', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'ĐT: 0902 869 579 - 0902 869 579', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'HOA DON TÍNH TIEN BẢN BIDALÖ 2', 'cate': 'info', 'cate_conf': '0.9783985'}
# {'sentence': 'Giờ bắt đầu: 41:23:27 13/04/2015', 'cate': 'info', 'cate_conf': '0.93447685'}
# {'sentence': 'Giờ kết thúc: 11:36:36 13/04/2015', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Thời gian: 0 giờ 13 phút', 'cate': 'info', 'cate_conf': '0.9980058'}
# {'sentence': 'Tên SL Giá Téng', 'cate': 'index', 'cate_conf': '0.9906059'}
# {'sentence': 'Bla Heniken 2 x 20.000 40.000', 'cate': 'content', 'cate_conf': '0.99988556'}
# {'sentence': 'Thuốc lá 4l: 4 25.000 25.000.', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Sling ex: 16.000 15.000', 'cate': 'content', 'cate_conf': '0.9621486'}
# {'sentence': 'Đậu 3 x 15.000 45.000', 'cate': 'content', 'cate_conf': '0.99999964'}
# {'sentence': '“Tổng dịch vụ: 125.000', 'cate': 'total', 'cate_conf': '0.75982535'}
# {'sentence': 'Tổng tiền giờ: 11.000', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'Tổng hóa đơn: 136.000', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'Tiên niở 50 000 đ/nlờ', 'cate': 'info', 'cate_conf': 1}
# {'sentence': '* MA HE) 1122271042015.', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Xin cim on va hen gặp lại quý khác]', 'cate': 'thank_you', 'cate_conf': '0.87995166'}
# {'sentence': 'Công Ty Công Nghệ Tin Học Mũi -', 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': 'Tên Vàng', 'cate': 'brand_name', 'cate_conf': '0.3911598'}
# {'sentence': 'WWW mtv.org.vn', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Số 7 Nam Quốc Cang, Quận 1,', 'cate': 'info', 'cate_conf': '0.9969861'}
# {'sentence': 'TP. Hỗ ChfíMinh', 'cate': 'info', 'cate_conf': '0.9859454'}
# {'sentence': '8.0 36100311.0', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'HOA DON', 'cate': 'info', 'cate_conf': '0.93414146'}
# {'sentence': 'Số CT: admin 151104 085639', 'cate': 'info', 'cate_conf': '0.9970688'}
# {'sentence': 'Ngày CT: 04/11/2015 - 08:56', 'cate': 'info', 'cate_conf': '0.99509865'}
# {'sentence': 'Khách hàng: Khách lẻ', 'cate': 'info', 'cate_conf': '0.9984901'}
# {'sentence': 'Điên thoai:', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Nhãn viên: Administrator', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'SL ĐGiá CK TTién', 'cate': 'index', 'cate_conf': '0.96821356'}
# {'sentence': 'Lẫu thái', 'cate': 'content', 'cate_conf': '0.73169553'}
# {'sentence': '4,00 130.000 0 130.000', 'cate': 'content', 'cate_conf': '0.67991537'}
# {'sentence': 'Cánh gà nướng', 'cate': 'content', 'cate_conf': '0.9992417'}
# {'sentence': '1,00 60.000 0 60.000', 'cate': 'content', 'cate_conf': '0.99989927'}
# {'sentence': 'Bè xào củ hành', 'cate': 'content', 'cate_conf': '0.99942696'}
# {'sentence': '1,00 65.000 0 65.000', 'cate': 'content', 'cate_conf': '0.9998957'}
# {'sentence': 'Heo rừng nướng ngũ vị', 'cate': 'content', 'cate_conf': '0.999997'}
# {'sentence': '4,00 65.000 0 65.000', 'cate': 'content', 'cate_conf': '0.99979824'}
# {'sentence': 'Càng ghe rang mudi', 'cate': 'content', 'cate_conf': '0.99886656'}
# {'sentence': '1,00 65.000 0 65.000', 'cate': 'content', 'cate_conf': '0.9998957'}
# {'sentence': 'Mi xảo bò', 'cate': 'content', 'cate_conf': '0.9984713'}
# {'sentence': '1,00 50.000 0 50.000', 'cate': 'content', 'cate_conf': '0.9968148'}
# {'sentence': 'Tổng cộng 435.000', 'cate': 'total', 'cate_conf': '0.8391366'}
# {'sentence': 'Thuế GTGT 0% 0', 'cate': 'total', 'cate_conf': '0.7982278'}
# {'sentence': 'PappaRich BMC', 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': 'NO.19 & 21', 'cate': 'info', 'cate_conf': '0.5289484'}
# {'sentence': 'JALAN TEMENGGUNG 23/9.', 'cate': 'info', 'cate_conf': '0.9216682'}
# {'sentence': 'BANDAR MAHKOTA CHERAS', 'cate': 'info', 'cate_conf': 1}
# {'sentence': '43200 SELANGDR DARUL EHSAN, MALAYSIA', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'TAX INVOICE', 'cate': 'info', 'cate_conf': '0.99993026'}
# {'sentence': 'GST 1D:000164270080', 'cate': 'info', 'cate_conf': 1}
# {'sentence': '| 2 COUNTER 2003 sai ful', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Chk 276703 Guest |', 'cate': 'info', 'cate_conf': 1}
# {'sentence': '29 Jun 18 06:01:34 PM', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'TBL35 / |', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'N22 SPRG NDL+sutcr E 9.34 §', 'cate': 'content', 'cate_conf': '0.5939048'}
# {'sentence': 'R02 N’ LMK+cco+st E 20.88 §', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'D27 MILD (ï) E 5.19 §', 'cate': 'content', 'cate_conf': '0.8461916'}
# {'sentence': '031 MOCHA (IT) E 7.45 §', 'cate': 'content', 'cate_conf': '0.862384'}
# {'sentence': 'CASH 58,80', 'cate': 'total', 'cate_conf': '0.9358105'}
# {'sentence': '42.64', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'Subtotal 42.64', 'cate': 'total', 'cate_conf': 1}
# {'sentence': '10% Srv Chg 4.25', 'cate': 'total', 'cate_conf': '0.87046957'}
# {'sentence': 'Total: 468.88', 'cate': 'total', 'cate_conf': '0.87647545'}
# {'sentence': 'RND ADJ 0.01', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'TTL ATF RND 46.90', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'Payment 56.90', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'Change Due 10.00', 'cate': 'total', 'cate_conf': '0.96380204'}
# {'sentence': '---2003 CLOSED 29 Jun 18 06:25:04 PM-~-', 'cate': 'info', 'cate_conf': '0.99612695'}
# {'sentence': 'THANK YOU! PLEASE COME AGAIN!', 'cate': 'thank_you', 'cate_conf': '0.9580079'}
# {'sentence': 'GST AT 0%', 'cate': 'info', 'cate_conf': '0.4585504'}
# {'sentence': 'GSTSummary Amount(RM) GST(RM)', 'cate': 'info', 'cate_conf': '0.28796932'}
# {'sentence': '§=§ST 80%: 46.90 0.00', 'cate': 'content', 'cate_conf': '0.98709977'}
# {'sentence': 'Z=GST @0%: 0.00 0.00', 'cate': 'total', 'cate_conf': '0.9322963'}
# {'sentence': 'G COFFEE', 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': 'a pees ee Be oe PCa', 'cate': 'total', 'cate_conf': 0}
# {'sentence': "faffE- pnH't7 1n hñnñ.", 'cate': 'info', 'cate_conf': 0}
# {'sentence': 'HÓA ĐƠN THANH TOÁN', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'UD', 'cate': 'total', 'cate_conf': 0}
# {'sentence': 'Ss F7, ĐC0:', 'cate': 'content', 'cate_conf': 0}
# {'sentence': 'ay 51v: Gia 10212.', 'cate': 'total', 'cate_conf': 0}
# {'sentence': 'BÀN', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Ped Haat - silo ke OT 2', 'cate': 'brand_name', 'cate_conf': 0}
# {'sentence': 'CAFE DEN TO 18.000 18000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '', 'cate': '', 'cate_conf': '0'}
# {'sentence': '".ncỔ 25) zZUUU d4:', 'cate': 'info', 'cate_conf': '0.89619094'}
# {'sentence': 'ZFamawisncoan. 2D. 280G7- 20,006', 'cate': 'total', 'cate_conf': '0.830748'}
# {'sentence': 'HA.', 'cate': 'info', 'cate_conf': '0.9035072'}
# {'sentence': '(ung XcBbmaoel, 2Ð 31721 Si ties', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': 'Mocha ‹Jc<Eitnidl TU: eo  23LL5Í', 'cate': 'info', 'cate_conf': '0.94531137'}
# {'sentence': 'ankgManm 1713 32005: 3200.', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': '-CRfEUceiriglce 20 30000 52001:', 'cate': 'total', 'cate_conf': '0.830748'}
# {'sentence': '“Bend >', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': 'JEnpimiecrin. AND! zãnan 25007', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': 'min. 40  2ãponu Sim', 'cate': 'total', 'cate_conf': '0.3770745'}
# {'sentence': 'ever depabecinas Oo aS op 350i', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': ':TONG CONG : 150: 404,000', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'TIEN MAT 404:000:', 'cate': 'total', 'cate_conf': '0.9694409'}
# {'sentence': '‘Ban tania boningan dong.', 'cate': 'total', 'cate_conf': '0.9849017'}
# {'sentence': "'§OTIENINHABHIBỨA —“ $00,000:", 'cate': 'total', 'cate_conf': '0.51311374'}
# {'sentence': "“SỞ 'TIÊN THÔI LAI 86,000", 'cate': 'total', 'cate_conf': '0.88107467'}
# {'sentence': "XIN GÀM 'ØN- HEN BÀP. LAIL", 'cate': 'thank_you', 'cate_conf': '0.7771016'}
# {'sentence': '| 17 Te muỗi Hà BLL} sso so =a sn', 'cate': 'info', 'cate_conf': '0.6961649'}
# {'sentence': 'Crea er a hin', 'cate': 'total', 'cate_conf': '0.9011917'}
# {'sentence': 'nã =.=.', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': '| 25] GIAM GIAS% ED ——} “6,144,000,', 'cate': 'total', 'cate_conf': '0.987201'}
# {'sentence': 'FT SO TEN, =-c=`', 'cate': 'info', 'cate_conf': '0.4606164'}
# {'sentence': '136,886,800', 'cate': 'info', 'cate_conf': '0.9266208'}
# {'sentence': '(ie hha don ch mm. IT nam 2016', 'cate': 'info', 'cate_conf': '0.9742166'}
# {'sentence': '(Ot hia Aon chưa bao dầm th. 4 <>.', 'cate': 'content', 'cate_conf': '0.90226793'}
# {'sentence': 'Công Ty Công Nghệ TinHoc Mai | |', 'cate': 'brand_name', 'cate_conf': 1}
# {'sentence': 'Tên Vàng', 'cate': 'brand_name', 'cate_conf': '0.3911598'}
# {'sentence': 'www.mtv.org.vn', 'cate': 'total', 'cate_conf': '0.3410359'}
# {'sentence': 'Sô 7 Nam Quôc Cang, Quận 1,', 'cate': 'info', 'cate_conf': '0.9978211'}
# {'sentence': 'TP. H6 ChiMinh', 'cate': 'info', 'cate_conf': '0.99960047'}
# {'sentence': '056100311', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'HOA DON', 'cate': 'info', 'cate_conf': '0.93414146'}
# {'sentence': 'S6CT: — admin 151104 0856393', 'cate': 'info', 'cate_conf': 1}
# {'sentence': 'Ngày CT: 04/11/2015 - 08:56', 'cate': 'info', 'cate_conf': '0.99509865'}
# {'sentence': 'Khách hàng: Khách lẻ.', 'cate': 'info', 'cate_conf': '0.9984901'}
# {'sentence': "'Điện thoại:", 'cate': 'info', 'cate_conf': '0.99650156'}
# {'sentence': 'Nhân viên: Administrator', 'cate': 'info', 'cate_conf': '0.9997782'}
# {'sentence': 'SL ĐGiá CK TTiền', 'cate': 'index', 'cate_conf': 1}
# {'sentence': 'Lầu thái', 'cate': 'content', 'cate_conf': '0.99260485'}
# {'sentence': '41,00 130.000 0 130000', 'cate': 'content', 'cate_conf': '0.7664441'}
# {'sentence': 'Cánh gà nướng', 'cate': 'content', 'cate_conf': '0.9992417'}
# {'sentence': '1,00 60,000 0 60.000', 'cate': 'total', 'cate_conf': 1}
# {'sentence': 'Bồ xào củ hành', 'cate': 'content', 'cate_conf': '0.9999714'}
# {'sentence': '4,00 65.000 0 65.000', 'cate': 'content', 'cate_conf': '0.99979824'}
# {'sentence': 'Heo rừng nướng ngữ vị', 'cate': 'content', 'cate_conf': '0.9999964'}
# {'sentence': '41,00 65000 09 6535000', 'cate': 'content', 'cate_conf': '0.99673516'}
# {'sentence': 'Càng ghẹ rang muối', 'cate': 'content', 'cate_conf': 1}
# {'sentence': '100.0 65.0 0.0 65.0', 'cate': 'content', 'cate_conf': '0.7230588'}
# {'sentence': 'Mì xảo bò.', 'cate': 'content', 'cate_conf': '0.9939162'}
# {'sentence': '1,00 50000 0 50.000', 'cate': 'content', 'cate_conf': 1}
# {'sentence': 'Tổng cộng 435.000', 'cate': 'total', 'cate_conf': '0.8391366'}
# {'sentence': 'Thué GTGT 0%', 'cate': 'total', 'cate_conf': '0.46625748'}
